# %% [markdown]
# # Phase 0-5: Clustering
#
# Uses UMAP to visualize the feature space, then lets you manually draw clusters.

# %%
import os
import pickle
import shutil
from pathlib import Path

import numpy as np
import umap
import matplotlib.pyplot as plt
from matplotlib.path import Path as MplPath
from matplotlib.patches import Polygon
from PIL import Image

print(f"Imports OK. CWD: {Path().resolve()}")

# %%
# Change this to your local path
PROJECT_ROOT = "/Users/tyreecruse/Desktop/CS230/Project/Data/Original"

CONFIG = {
    "datasetPath": os.path.join(PROJECT_ROOT, "master_dataset_pool"),
    "featuresPath": os.path.join(PROJECT_ROOT, "features.pkl"),
    "resultsDir": os.path.join(PROJECT_ROOT, "clustering_results"),
    "clusteredDir": os.path.join(PROJECT_ROOT, "clustered_images"),
    # UMAP params
    "nNeighbors": 15,
    "minDist": 0.1,
    "randomState": 42,
}

print("Config")
print("------")
print(f"Features: {CONFIG['featuresPath']}")
print(f"Results: {CONFIG['resultsDir']}")

datasetPath = Path(CONFIG["datasetPath"])
imagesDir = datasetPath / "images"

if datasetPath.exists():
    nImgs = len(list(imagesDir.glob("*"))) if imagesDir.exists() else 0
    print(f"\nFound {nImgs:,} images in dataset")

# %%
def loadFeatures(filepath):
    """Loads the features pickle from Phase 0-4.
    
    Args:
        filepath: path to features.pkl
    
    Returns:
        tuple of (features array, paths list, metadata dict)
    """
    filepath = Path(filepath)
    
    with open(filepath, "rb") as f:
        data = pickle.load(f)
    
    features = np.array(data["features"])
    paths = data["paths"]
    
    # everything else is metadata
    meta = {k: v for k, v in data.items() if k not in ["features", "paths"]}
    
    print(f"Loaded {features.shape[0]:,} features, dim={features.shape[1]}")
    
    return features, paths, meta


def fixPaths(paths, datasetPath):
    """Maps paths to the current dataset location.
    
    The paths in the pickle might be from a different machine,
    so we need to fix them to point to our local images/ folder.
    """
    imagesDir = Path(datasetPath) / "images"
    
    fixed = []
    for p in paths:
        name = os.path.basename(p)
        fixed.append(str(imagesDir / name))
    
    return fixed

# %%
def runUmap(features, config):
    """Runs UMAP to get 2D embedding.
    
    Args:
        features: (N, D) feature matrix
        config: dict with nNeighbors, minDist, randomState
    
    Returns:
        (N, 2) embedding array
    """
    print("Running UMAP...")
    
    reducer = umap.UMAP(
        n_neighbors=config.get("nNeighbors", 15),
        min_dist=config.get("minDist", 0.1),
        n_components=2,
        random_state=config.get("randomState", 42),
    )
    
    embedding = reducer.fit_transform(features)
    
    print(f"Embedding shape: {embedding.shape}")
    return embedding


def plotEmbedding(embedding, labels=None, title="UMAP"):
    """Plots the 2D embedding.
    
    Args:
        embedding: (N, 2) array
        labels: optional cluster labels for coloring
        title: plot title
    """
    plt.figure(figsize=(8, 6))
    
    if labels is not None:
        # color by cluster
        plt.scatter(embedding[:, 0], embedding[:, 1], 
                   c=labels, cmap="tab10", s=3, alpha=0.6)
    else:
        plt.scatter(embedding[:, 0], embedding[:, 1], s=3, alpha=0.5)
    
    plt.xlabel("UMAP 1")
    plt.ylabel("UMAP 2")
    plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
def manualClustering(embedding):
    """Interactive polygon-based clustering.
    
    You draw polygons on the UMAP plot to define clusters.
    Click vertices, press Enter when done with each polygon.
    Type 'n' when you don't want to add more clusters.
    
    Args:
        embedding: (N, 2) UMAP embedding
    
    Returns:
        tuple of (labels array, polygons dict)
    """
    nPoints = len(embedding)
    labels = np.full(nPoints, -1)  # -1 means unassigned
    polygons = {}
    
    # show the plot
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.scatter(embedding[:, 0], embedding[:, 1], s=3, alpha=0.5)
    ax.set_title("Click to draw polygon vertices, Enter when done")
    plt.show(block=False)
    
    clusterId = 0
    
    while True:
        resp = input(f"\nDefine cluster {clusterId}? [y/n]: ").strip().lower()
        
        if resp != "y":
            break
        
        print("Click polygon vertices, press Enter when done...")
        pts = plt.ginput(n=-1, timeout=0)
        
        if len(pts) < 3:
            print("Need at least 3 points, skipping")
            continue
        
        # find which points are inside the polygon
        polygon = MplPath(pts)
        inside = polygon.contains_points(embedding)
        
        # assign labels
        labels[inside] = clusterId
        polygons[clusterId] = pts
        
        nAssigned = inside.sum()
        print(f"Assigned {nAssigned:,} points to cluster {clusterId}")
        
        clusterId += 1
    
    # put remaining points in their own cluster
    unassigned = labels == -1
    if unassigned.any():
        labels[unassigned] = clusterId
        print(f"\n{unassigned.sum():,} points left in 'other' cluster {clusterId}")
    
    return labels, polygons

# %%
def printClusterSummary(labels):
    """Prints count per cluster."""
    print("\nCluster summary:")
    for k in np.unique(labels):
        n = (labels == k).sum()
        print(f"  Cluster {k}: {n:,} images")


def showClusterSamples(paths, labels, clusterId, nSamples=9):
    """Shows a grid of sample images from a cluster.
    
    Args:
        paths: list of image paths
        labels: cluster labels
        clusterId: which cluster to show
        nSamples: how many images
    """
    # get indices for this cluster
    indices = np.where(labels == clusterId)[0]
    
    if len(indices) == 0:
        print(f"No images in cluster {clusterId}")
        return
    
    # random sample
    nSamples = min(nSamples, len(indices))
    sampled = np.random.choice(indices, nSamples, replace=False)
    
    # figure out grid size
    nCols = int(np.ceil(np.sqrt(nSamples)))
    nRows = int(np.ceil(nSamples / nCols))
    
    fig, axes = plt.subplots(nRows, nCols, figsize=(3*nCols, 3*nRows))
    axes = np.array(axes).flatten()
    
    for i, idx in enumerate(sampled):
        ax = axes[i]
        try:
            img = Image.open(paths[idx])
            ax.imshow(img)
            ax.set_title(Path(paths[idx]).name, fontsize=8)
        except:
            ax.set_title("load error")
        ax.axis("off")
    
    # hide unused axes
    for ax in axes[nSamples:]:
        ax.axis("off")
    
    plt.suptitle(f"Cluster {clusterId} samples")
    plt.tight_layout()
    plt.show()

# %%
def saveClusterLists(paths, labels, outputDir):
    """Saves a text file for each cluster with the image paths.
    
    Args:
        paths: list of image paths
        labels: cluster labels
        outputDir: where to save the files
    """
    outputDir = Path(outputDir)
    outputDir.mkdir(parents=True, exist_ok=True)
    
    for k in np.unique(labels):
        indices = np.where(labels == k)[0]
        outFile = outputDir / f"cluster_{k:02d}.txt"
        
        with open(outFile, "w") as f:
            for i in indices:
                f.write(paths[i] + "\n")
        
        print(f"  Wrote {len(indices):,} paths to {outFile.name}")


def copyImagesToFolders(resultsDir, datasetPath, outputDir):
    """Copies images into separate folders per cluster.
    
    Reads the cluster_XX.txt files and copies images to outputDir/cluster_XX/
    """
    resultsDir = Path(resultsDir)
    outputDir = Path(outputDir)
    imagesDir = Path(datasetPath) / "images"
    
    txtFiles = sorted(resultsDir.glob("cluster_*.txt"))
    
    if not txtFiles:
        print("No cluster files found")
        return
    
    print("\nCopying images to folders...")
    
    for txtFile in txtFiles:
        clusterName = txtFile.stem
        clusterDir = outputDir / clusterName
        clusterDir.mkdir(parents=True, exist_ok=True)
        
        # read paths from file
        with open(txtFile) as f:
            paths = [line.strip() for line in f if line.strip()]
        
        nCopied = 0
        for p in paths:
            name = Path(p).name
            src = imagesDir / name
            dst = clusterDir / name
            
            if src.exists() and not dst.exists():
                shutil.copy2(src, dst)
                nCopied += 1
        
        print(f"  {clusterName}: copied {nCopied:,} images")

# %%
def main():
    """Main function - runs the whole clustering pipeline."""
    
    print("\n" + "="*50)
    print("CLUSTERING PIPELINE")
    print("="*50)
    
    # load features
    features, paths, meta = loadFeatures(CONFIG["featuresPath"])
    paths = fixPaths(paths, CONFIG["datasetPath"])
    
    # run UMAP
    embedding = runUmap(features, CONFIG)
    plotEmbedding(embedding, title="UMAP of CLIP features")
    
    # interactive clustering
    labels, polygons = manualClustering(embedding)
    printClusterSummary(labels)
    
    # show colored plot
    plotEmbedding(embedding, labels=labels, title="Clustered")
    
    # show samples from first cluster
    clusters = np.unique(labels)
    if len(clusters) > 0:
        showClusterSamples(paths, labels, clusters[0])
    
    # save results
    print("\nSaving cluster lists...")
    saveClusterLists(paths, labels, CONFIG["resultsDir"])
    copyImagesToFolders(CONFIG["resultsDir"], CONFIG["datasetPath"], 
                        CONFIG["clusteredDir"])
    
    print("\n" + "="*50)
    print("DONE")
    print("="*50)
    print(f"Results saved to: {CONFIG['resultsDir']}")
    print(f"Images copied to: {CONFIG['clusteredDir']}")
    
    return embedding, labels, polygons


if __name__ == "__main__":
    embedding, labels, polygons = main()

# %%
# Next steps
print("\nNEXT STEPS:")
print("-" * 40)
print("1. Check the clustered UMAP plot")
print("2. Look at sample images from each cluster")
print("3. Re-run manualClustering() if needed")
print(f"4. Images are in {CONFIG['clusteredDir']}")
print("5. Pick the 'normal' cluster for YOLO training")
