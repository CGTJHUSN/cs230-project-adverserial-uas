# %% [markdown]
# # Phase 0-3: Dataset Statistics
#
# Computes basic stats about the dataset - class distribution, bbox sizes, image resolutions.

# %%
import os
import json
from pathlib import Path
from collections import defaultdict
from datetime import datetime

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

print(f"Imports OK. CWD: {Path().resolve()}")

# %%
# Change this to your local path
PROJECT_ROOT = "/Users/tyreecruse/Desktop/CS230/Project/Data/Original"

CONFIG = {
    "datasetPath": os.path.join(PROJECT_ROOT, "master_dataset_pool"),
    "sampleSize": 1000,  # how many images to sample for resolution stats
    "saveReport": True,
    "reportDir": os.path.join(PROJECT_ROOT, "dataset_reports"),
}

print("Config")
print("------")
for key, val in CONFIG.items():
    print(f"{key}: {val}")

datasetPath = Path(CONFIG["datasetPath"])
imagesDir = datasetPath / "images"
labelsDir = datasetPath / "labels"

if datasetPath.exists():
    nImg = len(list(imagesDir.glob("*"))) if imagesDir.exists() else 0
    nLbl = len(list(labelsDir.glob("*.txt"))) if labelsDir.exists() else 0
    print(f"\nFound {nImg:,} images, {nLbl:,} labels")
else:
    print(f"\n[warning] dataset not found")

# %%
def getClassDistribution(labelsDir):
    """Counts how many bboxes per class and per image.
    
    Args:
        labelsDir: path to labels folder
    
    Returns:
        dict with classCounts, boxesPerImage list, and summary stats
    """
    labelsDir = Path(labelsDir)
    
    classCounts = defaultdict(int)
    boxesPerImage = []
    totalBoxes = 0
    
    if not labelsDir.is_dir():
        return {"classCounts": {}, "numClasses": 0, "totalBoxes": 0}
    
    labelFiles = list(labelsDir.glob("*.txt"))
    
    for labelPath in labelFiles:
        nBoxes = 0
        try:
            lines = labelPath.read_text().strip().splitlines()
        except:
            continue
        
        for line in lines:
            parts = line.strip().split()
            if len(parts) != 5:
                continue
            try:
                classId = int(parts[0])
                classCounts[classId] += 1
                nBoxes += 1
                totalBoxes += 1
            except:
                continue
        
        boxesPerImage.append(nBoxes)
    
    # compute stats
    result = {
        "classCounts": dict(classCounts),
        "numClasses": len(classCounts),
        "totalBoxes": totalBoxes,
        "boxesPerImage": boxesPerImage,
    }
    
    if boxesPerImage:
        arr = np.array(boxesPerImage)
        result["avgBoxesPerImage"] = float(arr.mean())
        result["minBoxes"] = int(arr.min())
        result["maxBoxes"] = int(arr.max())
    
    return result

# %%
def getBboxStats(labelsDir, maxFiles=1000):
    """Gets stats about bounding box sizes.
    
    Args:
        labelsDir: path to labels folder
        maxFiles: only process this many files (for speed)
    
    Returns:
        dict with width/height/area lists and averages
    """
    labelsDir = Path(labelsDir)
    
    widths = []
    heights = []
    areas = []
    aspectRatios = []
    
    labelFiles = sorted(labelsDir.glob("*.txt"))[:maxFiles]
    
    for labelPath in labelFiles:
        try:
            lines = labelPath.read_text().strip().splitlines()
        except:
            continue
        
        for line in lines:
            parts = line.strip().split()
            if len(parts) != 5:
                continue
            
            try:
                _, x, y, w, h = [float(p) for p in parts]
            except:
                continue
            
            widths.append(w)
            heights.append(h)
            areas.append(w * h)
            if h > 0:
                aspectRatios.append(w / h)
    
    result = {
        "widths": widths,
        "heights": heights,
        "areas": areas,
        "aspectRatios": aspectRatios,
    }
    
    # compute averages
    if widths:
        result["avgWidth"] = float(np.mean(widths))
        result["avgHeight"] = float(np.mean(heights))
        result["avgArea"] = float(np.mean(areas))
    
    return result

# %%
def getImageResolutions(imagesDir, sampleSize=1000):
    """Gets resolution stats from a sample of images.
    
    Args:
        imagesDir: path to images folder
        sampleSize: how many images to check
    
    Returns:
        dict with width/height lists and summary stats
    """
    imagesDir = Path(imagesDir)
    
    widths = []
    heights = []
    
    imageFiles = sorted([p for p in imagesDir.glob("*") if p.is_file()])
    if sampleSize > 0:
        imageFiles = imageFiles[:sampleSize]
    
    for imgPath in imageFiles:
        try:
            with Image.open(imgPath) as img:
                w, h = img.size
                widths.append(w)
                heights.append(h)
        except:
            continue
    
    result = {
        "widths": widths,
        "heights": heights,
    }
    
    if widths:
        result["avgWidth"] = float(np.mean(widths))
        result["avgHeight"] = float(np.mean(heights))
        result["minWidth"] = int(min(widths))
        result["maxWidth"] = int(max(widths))
        result["minHeight"] = int(min(heights))
        result["maxHeight"] = int(max(heights))
    
    return result

# %%
def analyzeDataset(datasetPath, config):
    """Runs all the analysis and returns a big dict of stats."""
    datasetPath = Path(datasetPath)
    imagesDir = datasetPath / "images"
    labelsDir = datasetPath / "labels"
    
    # count files
    imageFiles = list(imagesDir.glob("*")) if imagesDir.is_dir() else []
    labelFiles = list(labelsDir.glob("*.txt")) if labelsDir.is_dir() else []
    
    nImages = len(imageFiles)
    nLabels = len(labelFiles)
    
    print(f"\nImages: {nImages:,}")
    print(f"Labels: {nLabels:,}")
    if nImages > 0:
        print(f"Coverage: {100*nLabels/nImages:.1f}%")
    
    # class distribution
    print("\nAnalyzing class distribution...")
    classStats = getClassDistribution(labelsDir)
    print(f"  Classes: {classStats['numClasses']}")
    print(f"  Total bboxes: {classStats['totalBoxes']:,}")
    if "avgBoxesPerImage" in classStats:
        print(f"  Avg boxes/image: {classStats['avgBoxesPerImage']:.2f}")
    
    # bbox dimensions
    print("\nAnalyzing bbox dimensions...")
    bboxStats = getBboxStats(labelsDir)
    if "avgWidth" in bboxStats:
        print(f"  Avg width: {bboxStats['avgWidth']:.3f}")
        print(f"  Avg height: {bboxStats['avgHeight']:.3f}")
        print(f"  Avg area: {bboxStats['avgArea']:.4f}")
    
    # image resolutions
    print("\nAnalyzing image resolutions...")
    resStats = getImageResolutions(imagesDir, config.get("sampleSize", 1000))
    if "avgWidth" in resStats:
        print(f"  Avg size: {resStats['avgWidth']:.0f} x {resStats['avgHeight']:.0f}")
        print(f"  Width range: {resStats['minWidth']} - {resStats['maxWidth']}")
        print(f"  Height range: {resStats['minHeight']} - {resStats['maxHeight']}")
    
    # bundle it all up
    analysis = {
        "timestamp": datetime.now().isoformat(),
        "datasetPath": str(datasetPath),
        "nImages": nImages,
        "nLabels": nLabels,
        "classStats": classStats,
        "bboxStats": bboxStats,
        "resStats": resStats,
    }
    
    return analysis

# %%
def plotClassDistribution(analysis):
    """Bar chart of class counts."""
    classCounts = analysis["classStats"].get("classCounts", {})
    if not classCounts:
        print("No class data to plot")
        return
    
    classes = sorted(classCounts.keys())
    counts = [classCounts[c] for c in classes]
    
    plt.figure(figsize=(8, 4))
    plt.bar(classes, counts)
    plt.xlabel("Class ID")
    plt.ylabel("Count")
    plt.title("Class Distribution")
    plt.tight_layout()
    plt.show()


def plotBboxAreas(analysis):
    """Histogram of bbox areas."""
    areas = analysis["bboxStats"].get("areas", [])
    if not areas:
        print("No bbox data to plot")
        return
    
    plt.figure(figsize=(8, 4))
    plt.hist(areas, bins=30)
    plt.xlabel("Normalized Area (w * h)")
    plt.ylabel("Count")
    plt.title("Bounding Box Area Distribution")
    plt.tight_layout()
    plt.show()


def plotImageResolutions(analysis):
    """Scatter plot of image dimensions."""
    widths = analysis["resStats"].get("widths", [])
    heights = analysis["resStats"].get("heights", [])
    
    if not widths:
        print("No resolution data to plot")
        return
    
    plt.figure(figsize=(6, 6))
    plt.scatter(widths, heights, s=5, alpha=0.5)
    plt.xlabel("Width (px)")
    plt.ylabel("Height (px)")
    plt.title("Image Resolutions")
    plt.tight_layout()
    plt.show()

# %%
def saveReport(analysis, config):
    """Saves a JSON report (without the huge arrays)."""
    reportDir = Path(config["reportDir"])
    reportDir.mkdir(parents=True, exist_ok=True)
    
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    reportPath = reportDir / f"stats_{ts}.json"
    
    # make a copy without the big lists
    reportData = {
        "timestamp": analysis["timestamp"],
        "datasetPath": analysis["datasetPath"],
        "nImages": analysis["nImages"],
        "nLabels": analysis["nLabels"],
    }
    
    # add class stats but skip the per-image list
    cs = analysis["classStats"]
    reportData["classStats"] = {
        "classCounts": cs.get("classCounts"),
        "numClasses": cs.get("numClasses"),
        "totalBoxes": cs.get("totalBoxes"),
        "avgBoxesPerImage": cs.get("avgBoxesPerImage"),
    }
    
    # bbox stats - just the averages
    bs = analysis["bboxStats"]
    reportData["bboxStats"] = {
        "avgWidth": bs.get("avgWidth"),
        "avgHeight": bs.get("avgHeight"),
        "avgArea": bs.get("avgArea"),
    }
    
    # resolution stats
    rs = analysis["resStats"]
    reportData["resStats"] = {
        "avgWidth": rs.get("avgWidth"),
        "avgHeight": rs.get("avgHeight"),
        "minWidth": rs.get("minWidth"),
        "maxWidth": rs.get("maxWidth"),
    }
    
    with open(reportPath, "w") as f:
        json.dump(reportData, f, indent=2)
    
    print(f"\nSaved report to {reportPath}")
    return reportPath

# %%
def main():
    """Run all the analysis and make plots."""
    analysis = analyzeDataset(CONFIG["datasetPath"], CONFIG)
    
    if CONFIG.get("saveReport", False):
        saveReport(analysis, CONFIG)
    
    return analysis


if __name__ == "__main__":
    analysis = main()

# %%
# make the plots
if "analysis" in dir():
    plotClassDistribution(analysis)
    plotBboxAreas(analysis)
    plotImageResolutions(analysis)
